# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Read CSV data and save as Pandas DataFrame
data_movies = pd.read_csv("data/IMDb movies.csv")
data_names = pd.read_csv("data/IMDb names.csv")
data_ratings = pd.read_csv("data/IMDb ratings.csv")
data_title_principals = pd.read_csv("data/IMDb title_principals.csv")

df_movies = pd.DataFrame(data_movies)
df_names = pd.DataFrame(data_names)
df_ratings = pd.DataFrame(data_ratings)
df_title = pd.DataFrame(data_title_principals)
# Out:
# C:\Users\WelanR_01\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_movies.dtypes
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                      object
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
df_names.dtypes
# Out:
# imdb_name_id              object
# name                      object
# birth_name                object
# height                   float64
# bio                       object
# birth_details             object
# date_of_birth             object
# place_of_birth            object
# death_details             object
# date_of_death             object
# place_of_death            object
# reason_of_death           object
# spouses_string            object
# spouses                    int64
# divorces                   int64
# spouses_with_children      int64
# children                   int64
# dtype: object

# %%
df_ratings.dtypes
# Out:
# imdb_title_id                 object
# weighted_average_vote        float64
# total_votes                    int64
# mean_vote                    float64
# median_vote                  float64
# votes_10                       int64
# votes_9                        int64
# votes_8                        int64
# votes_7                        int64
# votes_6                        int64
# votes_5                        int64
# votes_4                        int64
# votes_3                        int64
# votes_2                        int64
# votes_1                        int64
# allgenders_0age_avg_vote     float64
# allgenders_0age_votes        float64
# allgenders_18age_avg_vote    float64
# allgenders_18age_votes       float64
# allgenders_30age_avg_vote    float64
# allgenders_30age_votes       float64
# allgenders_45age_avg_vote    float64
# allgenders_45age_votes       float64
# males_allages_avg_vote       float64
# males_allages_votes          float64
# males_0age_avg_vote          float64
# males_0age_votes             float64
# males_18age_avg_vote         float64
# males_18age_votes            float64
# males_30age_avg_vote         float64
# males_30age_votes            float64
# males_45age_avg_vote         float64
# males_45age_votes            float64
# females_allages_avg_vote     float64
# females_allages_votes        float64
# females_0age_avg_vote        float64
# females_0age_votes           float64
# females_18age_avg_vote       float64
# females_18age_votes          float64
# females_30age_avg_vote       float64
# females_30age_votes          float64
# females_45age_avg_vote       float64
# females_45age_votes          float64
# top1000_voters_rating        float64
# top1000_voters_votes         float64
# us_voters_rating             float64
# us_voters_votes              float64
# non_us_voters_rating         float64
# non_us_voters_votes          float64
# dtype: object

# %%
df_title.dtypes
# Out:
# imdb_title_id    object
# ordering          int64
# imdb_name_id     object
# category         object
# job              object
# characters       object
# dtype: object

# %%
cleaned_df = df_movies.dropna()

# %%
cleaned_df
# Out:
#       imdb_title_id                          title  \
# 506       tt0017136                     Metropolis
# 1048      tt0021749               Luci della città
# 2454      tt0027977                  Tempi moderni
# 2795      tt0029453        Il bandito della Casbah
# 2827      tt0029583      Biancaneve e i sette nani
# ...             ...                            ...
# 85266     tt9208444  Impractical Jokers: The Movie
# 85274     tt9214832                          Emma.
# 85397     tt9354944                           Jexi
# 85460     tt9426210            Weathering with You
# 85740     tt9779516            Cosa mi lasci di te
#
#                         original_title  year date_published  \
# 506                         Metropolis  1927     1928-10-01
# 1048                       City Lights  1931     1931-04-02
# 2454                      Modern Times  1936     1937-03-12
# 2795                      Pépé le Moko  1937     1937-10-22
# 2827   Snow White and the Seven Dwarfs  1937     1938-11-30
# ...                                ...   ...            ...
# 85266    Impractical Jokers: The Movie  2020     2020-02-28
# 85274                            Emma.  2020     2020-03-27
# 85397                             Jexi  2019     2019-10-11
# 85460                      Tenki no ko  2019     2019-10-14
# 85740                  I Still Believe  2020     2020-03-19
#
#                             genre  duration       country        language  \
# 506                 Drama, Sci-Fi       153       Germany          German
# 1048       Comedy, Drama, Romance        87           USA         English
# 2454        Comedy, Drama, Family        87           USA         English
# 2795        Crime, Drama, Romance        94        France  French, Arabic
# 2827   Animation, Family, Fantasy        83           USA         English
# ...                           ...       ...           ...             ...
# 85266                      Comedy        92           USA         English
# 85274               Comedy, Drama       124            UK         English
# 85397             Comedy, Romance        84   USA, Canada         English
# 85460    Animation, Drama, Family       112  Japan, China        Japanese
# 85740     Biography, Drama, Music       116           USA         English
#
#                            director  ...  \
# 506                      Fritz Lang  ...
# 1048                Charles Chaplin  ...
# 2454                Charles Chaplin  ...
# 2795                Julien Duvivier  ...
# 2827   William Cottrell, David Hand  ...
# ...                             ...  ...
# 85266                  Chris Henchy  ...
# 85274               Autumn de Wilde  ...
# 85397        Jon Lucas, Scott Moore  ...
# 85460                Makoto Shinkai  ...
# 85740       Andrew Erwin, Jon Erwin  ...
#
#                                                   actors  \
# 506    Alfred Abel, Gustav Fröhlich, Rudolf Klein-Rog...
# 1048   Virginia Cherrill, Florence Lee, Harry Myers, ...
# 2454   Charles Chaplin, Paulette Goddard, Henry Bergm...
# 2795   Jean Gabin, Gabriel Gabrio, Saturnin Fabre, Fe...
# 2827   Roy Atwell, Stuart Buchanan, Adriana Caselotti...
# ...                                                  ...
# 85266  Paula Abdul, Joe Gatto, James Murray, Brian Qu...
# 85274  Anya Taylor-Joy, Angus Imrie, Letty Thomas, Ge...
# 85397  Adam Devine, Alexandra Shipp, Rose Byrne, Ron ...
# 85460  Kotaro Daigo, Nana Mori, Shun Oguri, Sei Hirai...
# 85740  K.J. Apa, Britt Robertson, Nathan Parsons, Gar...
#
#                                              description avg_vote   votes  \
# 506    In a futuristic city sharply divided between t...      8.3  156076
# 1048   With the aid of a wealthy erratic tippler, a d...      8.5  162668
# 2454   The Tramp struggles to live in modern industri...      8.5  211250
# 2795   A wanted gangster is both king and prisoner of...      7.7    6180
# 2827   Exiled into the dangerous forest by her wicked...      7.6  177157
# ...                                                  ...      ...     ...
# 85266  The story of a humiliating high school mishap ...      5.9    4105
# 85274  In 1800s England, a well meaning but selfish y...      6.7   19858
# 85397  A comedy about what can happen when you love y...      6.1   17038
# 85460  A high-school boy who has run away to Tokyo be...      7.6   16277
# 85740  The true-life story of Christian music star Je...      6.5    6196
#
#             budget  usa_gross_income worlwide_gross_income metascore  \
# 506    DEM 6000000         $ 1236166             $ 1349711      98.0
# 1048     $ 1500000           $ 19181               $ 46008      99.0
# 2454     $ 1500000          $ 163577              $ 457688      96.0
# 2795       $ 60000          $ 155895              $ 155895      98.0
# 2827     $ 1499000       $ 184925486           $ 184925486      95.0
# ...            ...               ...                   ...       ...
# 85266    $ 3000000        $ 10691091            $ 10691091      39.0
# 85274   $ 10000000        $ 10055355            $ 25659965      71.0
# 85397    $ 5000000         $ 6546159             $ 9341824      39.0
# 85460   $ 11100000         $ 7798743           $ 193176979      72.0
# 85740   $ 12000000         $ 9868521            $ 13681524      41.0
#
#       reviews_from_users  reviews_from_critics
# 506                495.0                 208.0
# 1048               295.0                 122.0
# 2454               307.0                 115.0
# 2795                46.0                  55.0
# 2827               260.0                 173.0
# ...                  ...                   ...
# 85266              152.0                  17.0
# 85274              314.0                 188.0
# 85397              234.0                  42.0
# 85460              177.0                 110.0
# 85740              151.0                  52.0
#
# [6616 rows x 22 columns]

# %%
cleaned_df.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
reduced_df = cleaned_df[['original_title', 'year',
       'genre', 'duration', 'country', 'director', 'writer',
       'production_company', 'actors', 'avg_vote', 'votes',
       'budget', 'worlwide_gross_income']]

reduced_df
# Out:
#                         original_title  year                       genre  \
# 506                         Metropolis  1927               Drama, Sci-Fi
# 1048                       City Lights  1931      Comedy, Drama, Romance
# 2454                      Modern Times  1936       Comedy, Drama, Family
# 2795                      Pépé le Moko  1937       Crime, Drama, Romance
# 2827   Snow White and the Seven Dwarfs  1937  Animation, Family, Fantasy
# ...                                ...   ...                         ...
# 85266    Impractical Jokers: The Movie  2020                      Comedy
# 85274                            Emma.  2020               Comedy, Drama
# 85397                             Jexi  2019             Comedy, Romance
# 85460                      Tenki no ko  2019    Animation, Drama, Family
# 85740                  I Still Believe  2020     Biography, Drama, Music
#
#        duration       country                      director  \
# 506         153       Germany                    Fritz Lang
# 1048         87           USA               Charles Chaplin
# 2454         87           USA               Charles Chaplin
# 2795         94        France               Julien Duvivier
# 2827         83           USA  William Cottrell, David Hand
# ...         ...           ...                           ...
# 85266        92           USA                  Chris Henchy
# 85274       124            UK               Autumn de Wilde
# 85397        84   USA, Canada        Jon Lucas, Scott Moore
# 85460       112  Japan, China                Makoto Shinkai
# 85740       116           USA       Andrew Erwin, Jon Erwin
#
#                                  writer                   production_company  \
# 506    Thea von Harbou, Thea von Harbou                 Universum Film (UFA)
# 1048                    Charles Chaplin          Charles Chaplin Productions
# 2454                    Charles Chaplin          Charles Chaplin Productions
# 2795   Henri La Barthe, Henri La Barthe                           Paris Film
# 2827         Jacob Grimm, Wilhelm Grimm              Walt Disney Productions
# ...                                 ...                                  ...
# 85266           Chris Henchy, Joe Gatto                         Funny or Die
# 85274       Eleanor Catton, Jane Austen                  Working Title Films
# 85397            Jon Lucas, Scott Moore                            CBS Films
# 85460                    Makoto Shinkai  "Weathering With You" Film Partners
# 85740            Jeremy Camp, Jon Erwin             Kevin Downes Productions
#
#                                                   actors  avg_vote   votes  \
# 506    Alfred Abel, Gustav Fröhlich, Rudolf Klein-Rog...       8.3  156076
# 1048   Virginia Cherrill, Florence Lee, Harry Myers, ...       8.5  162668
# 2454   Charles Chaplin, Paulette Goddard, Henry Bergm...       8.5  211250
# 2795   Jean Gabin, Gabriel Gabrio, Saturnin Fabre, Fe...       7.7    6180
# 2827   Roy Atwell, Stuart Buchanan, Adriana Caselotti...       7.6  177157
# ...                                                  ...       ...     ...
# 85266  Paula Abdul, Joe Gatto, James Murray, Brian Qu...       5.9    4105
# 85274  Anya Taylor-Joy, Angus Imrie, Letty Thomas, Ge...       6.7   19858
# 85397  Adam Devine, Alexandra Shipp, Rose Byrne, Ron ...       6.1   17038
# 85460  Kotaro Daigo, Nana Mori, Shun Oguri, Sei Hirai...       7.6   16277
# 85740  K.J. Apa, Britt Robertson, Nathan Parsons, Gar...       6.5    6196
#
#             budget worlwide_gross_income
# 506    DEM 6000000             $ 1349711
# 1048     $ 1500000               $ 46008
# 2454     $ 1500000              $ 457688
# 2795       $ 60000              $ 155895
# 2827     $ 1499000           $ 184925486
# ...            ...                   ...
# 85266    $ 3000000            $ 10691091
# 85274   $ 10000000            $ 25659965
# 85397    $ 5000000             $ 9341824
# 85460   $ 11100000           $ 193176979
# 85740   $ 12000000            $ 13681524
#
# [6616 rows x 13 columns]

# %%
df_movies["country"].value_counts()
# Out:
# USA                                                28511
# India                                               6065
# UK                                                  4111
# Japan                                               3077
# France                                              3055
#                                                    ...
# UK, USA, Ireland, Luxembourg, France                   1
# France, Myanmar                                        1
# Belgium, France, Luxembourg, Italy, Switzerland        1
# Colombia, Argentina, Uruguay, Spain, France            1
# Paraguay, Argentina                                    1
# Name: country, Length: 4907, dtype: int64

# %%
usa_df = reduced_df.loc[reduced_df["budget"].str.contains("$"),:]
usa_df
# Out:
#                         original_title  year                       genre  \
# 506                         Metropolis  1927               Drama, Sci-Fi
# 1048                       City Lights  1931      Comedy, Drama, Romance
# 2454                      Modern Times  1936       Comedy, Drama, Family
# 2795                      Pépé le Moko  1937       Crime, Drama, Romance
# 2827   Snow White and the Seven Dwarfs  1937  Animation, Family, Fantasy
# ...                                ...   ...                         ...
# 85266    Impractical Jokers: The Movie  2020                      Comedy
# 85274                            Emma.  2020               Comedy, Drama
# 85397                             Jexi  2019             Comedy, Romance
# 85460                      Tenki no ko  2019    Animation, Drama, Family
# 85740                  I Still Believe  2020     Biography, Drama, Music
#
#        duration       country                      director  \
# 506         153       Germany                    Fritz Lang
# 1048         87           USA               Charles Chaplin
# 2454         87           USA               Charles Chaplin
# 2795         94        France               Julien Duvivier
# 2827         83           USA  William Cottrell, David Hand
# ...         ...           ...                           ...
# 85266        92           USA                  Chris Henchy
# 85274       124            UK               Autumn de Wilde
# 85397        84   USA, Canada        Jon Lucas, Scott Moore
# 85460       112  Japan, China                Makoto Shinkai
# 85740       116           USA       Andrew Erwin, Jon Erwin
#
#                                  writer                   production_company  \
# 506    Thea von Harbou, Thea von Harbou                 Universum Film (UFA)
# 1048                    Charles Chaplin          Charles Chaplin Productions
# 2454                    Charles Chaplin          Charles Chaplin Productions
# 2795   Henri La Barthe, Henri La Barthe                           Paris Film
# 2827         Jacob Grimm, Wilhelm Grimm              Walt Disney Productions
# ...                                 ...                                  ...
# 85266           Chris Henchy, Joe Gatto                         Funny or Die
# 85274       Eleanor Catton, Jane Austen                  Working Title Films
# 85397            Jon Lucas, Scott Moore                            CBS Films
# 85460                    Makoto Shinkai  "Weathering With You" Film Partners
# 85740            Jeremy Camp, Jon Erwin             Kevin Downes Productions
#
#                                                   actors  avg_vote   votes  \
# 506    Alfred Abel, Gustav Fröhlich, Rudolf Klein-Rog...       8.3  156076
# 1048   Virginia Cherrill, Florence Lee, Harry Myers, ...       8.5  162668
# 2454   Charles Chaplin, Paulette Goddard, Henry Bergm...       8.5  211250
# 2795   Jean Gabin, Gabriel Gabrio, Saturnin Fabre, Fe...       7.7    6180
# 2827   Roy Atwell, Stuart Buchanan, Adriana Caselotti...       7.6  177157
# ...                                                  ...       ...     ...
# 85266  Paula Abdul, Joe Gatto, James Murray, Brian Qu...       5.9    4105
# 85274  Anya Taylor-Joy, Angus Imrie, Letty Thomas, Ge...       6.7   19858
# 85397  Adam Devine, Alexandra Shipp, Rose Byrne, Ron ...       6.1   17038
# 85460  Kotaro Daigo, Nana Mori, Shun Oguri, Sei Hirai...       7.6   16277
# 85740  K.J. Apa, Britt Robertson, Nathan Parsons, Gar...       6.5    6196
#
#             budget worlwide_gross_income
# 506    DEM 6000000             $ 1349711
# 1048     $ 1500000               $ 46008
# 2454     $ 1500000              $ 457688
# 2795       $ 60000              $ 155895
# 2827     $ 1499000           $ 184925486
# ...            ...                   ...
# 85266    $ 3000000            $ 10691091
# 85274   $ 10000000            $ 25659965
# 85397    $ 5000000             $ 9341824
# 85460   $ 11100000           $ 193176979
# 85740   $ 12000000            $ 13681524
#
# [6616 rows x 13 columns]

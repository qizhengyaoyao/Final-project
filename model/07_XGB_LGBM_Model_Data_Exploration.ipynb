# %%
import pandas as pd
from matplotlib import pyplot
import seaborn as sns

# %%
xgb_rate_df = pd.DataFrame(pd.read_csv("encoded_data/select_sample_data_rate_xgb.csv"))
lgbm_rate_df = pd.DataFrame(pd.read_csv("encoded_data/select_sample_data_rate_lgbm.csv"))

# %%
xgb_rate_df.head()
# Out:
#    year  duration   votes  budget  day  language_English  language_Spanish  \
# 0  1920        76   55601   18000   58                 0                 0
# 1  1921       150    3058  800000  106                 0                 0
# 2  1921        68  109038  250000  330                 1                 0
# 3  1923        82    4735  351000  157                 1                 0
# 4  1925        95   97480  923000  296                 1                 0
#
#    language_French  language_Russian  language_German  ...  \
# 0                0                 0                1  ...
# 1                0                 0                0  ...
# 2                0                 0                0  ...
# 3                0                 0                0  ...
# 4                0                 0                0  ...
#
#    actor_Queen Latifah  actor_Demián Bichir  actor_Natascha McElhone  \
# 0                    0                    0                        0
# ...
